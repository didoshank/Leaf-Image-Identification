# %% [markdown]
# ## Loading Libraries

# %%
# Import Data Science Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Tensorflow Libraries
from tensorflow import keras
from tensorflow.keras import layers,models
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
#from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model
from tensorflow.keras.layers.experimental import preprocessing

# System libraries
from pathlib import Path
import os.path

# Metrics
from sklearn.metrics import classification_report, confusion_matrix
import itertools

# %%
### We create a bunch of helpful functions throughout the course.
### Storing them here so they're easily accessible.

import tensorflow as tf

# Create a function to import an image and resize it to be able to be used with our model
def load_and_prep_image(filename, img_shape=224, scale=True):
  """
  Reads in an image from filename, turns it into a tensor and reshapes into
  (224, 224, 3).
  Parameters
  ----------
  filename (str): string filename of target image
  img_shape (int): size to resize target image to, default 224
  scale (bool): whether to scale pixel values to range(0, 1), default True
  """
  # Read in the image
  img = tf.io.read_file(filename)
  # Decode it into a tensor
  img = tf.image.decode_jpeg(img)
  # Resize the image
  img = tf.image.resize(img, [img_shape, img_shape])
  if scale:
    # Rescale the image (get all values between 0 and 1)
    return img/255.
  else:
    return img

# Note: The following confusion matrix code is a remix of Scikit-Learn's 
# plot_confusion_matrix function - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.
  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.
  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
    norm: normalize values or not (default=False).
    savefig: save confusion matrix to file (default=False).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.
  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if norm:
      plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
    else:
      plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

  # Save the figure to the current working directory
  if savefig:
    fig.savefig("confusion_matrix.png")
  
# Make a function to predict on images and plot them (works with multi-class)
def pred_and_plot(model, filename, class_names):
  """
  Imports an image located at filename, makes a prediction on it with
  a trained model and plots the image with the predicted class as the title.
  """
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))

  # Get the predicted class
  if len(pred[0]) > 1: # check for multi-class
    pred_class = class_names[pred.argmax()] # if more than one output, take the max
  else:
    pred_class = class_names[int(tf.round(pred)[0][0])] # if only one output, round

  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f"Prediction: {pred_class}")
  plt.axis(False);
  
import datetime

def create_tensorboard_callback(dir_name, experiment_name):
  """
  Creates a TensorBoard callback instand to store log files.
  Stores log files with the filepath:
    "dir_name/experiment_name/current_datetime/"
  Args:
    dir_name: target directory to store TensorBoard log files
    experiment_name: name of experiment directory (e.g. efficientnet_model_1)
  """
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# Plot the validation and training data separately
import matplotlib.pyplot as plt

def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

def compare_historys(original_history, new_history, initial_epochs=5):
    """
    Compares two TensorFlow model History objects.
    
    Args:
      original_history: History object from original model (before new_history)
      new_history: History object from continued model training (after original_history)
      initial_epochs: Number of epochs in original_history (new_history plot starts from here) 
    """
    
    # Get original history measurements
    acc = original_history.history["accuracy"]
    loss = original_history.history["loss"]

    val_acc = original_history.history["val_accuracy"]
    val_loss = original_history.history["val_loss"]

    # Combine original history with new history
    total_acc = acc + new_history.history["accuracy"]
    total_loss = loss + new_history.history["loss"]

    total_val_acc = val_acc + new_history.history["val_accuracy"]
    total_val_loss = val_loss + new_history.history["val_loss"]

    # Make plots
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(total_acc, label='Training Accuracy')
    plt.plot(total_val_acc, label='Validation Accuracy')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(total_loss, label='Training Loss')
    plt.plot(total_val_loss, label='Validation Loss')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()
  
# Create function to unzip a zipfile into current working directory 
# (since we're going to be downloading and unzipping a few files)
import zipfile

def unzip_data(filename):
  """
  Unzips filename into the current working directory.
  Args:
    filename (str): a filepath to a target zip folder to be unzipped.
  """
  zip_ref = zipfile.ZipFile(filename, "r")
  zip_ref.extractall()
  zip_ref.close()

# Walk through an image classification directory and find out how many files (images)
# are in each subdirectory.
import os

def walk_through_dir(dir_path):
  """
  Walks through dir_path returning its contents.
  Args:
    dir_path (str): target directory
  
  Returns:
    A print out of:
      number of subdiretories in dir_path
      number of images (files) in each subdirectory
      name of each subdirectory
  """
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
    
# Function to evaluate: accuracy, precision, recall, f1-score
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def calculate_results(y_true, y_pred):
  """
  Calculates model accuracy, precision, recall and f1 score of a binary classification model.
  Args:
      y_true: true labels in the form of a 1D array
      y_pred: predicted labels in the form of a 1D array
  Returns a dictionary of accuracy, precision, recall, f1-score.
  """
  # Calculate model accuracy
  model_accuracy = accuracy_score(y_true, y_pred) * 100
  # Calculate model precision, recall and f1 score using "weighted average
  model_precision, model_recall, model_f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
  model_results = {"accuracy": model_accuracy,
                  "precision": model_precision,
                  "recall": model_recall,
                  "f1": model_f1}
  return model_results

# %% [markdown]
# ## Load and Transform Data

# %%
BATCH_SIZE = 32
IMAGE_SIZE = (300, 300)

# %%
# Walk through each directory
dataset = r"D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset"
walk_through_dir(dataset);
# Out:
# There are 79 directories and 0 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset'.
# There are 0 directories and 73 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Abrus Precatorius (Rosary Pea)'.
# There are 0 directories and 124 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Acalypha Indica (Indian CopperLeaf)'.
# There are 0 directories and 54 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Achyranthes Aspera (Prickly Chaff Flower)'.
# There are 0 directories and 80 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Acorus Calamus (Sweet flag)'.
# There are 0 directories and 78 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Aerva Lanata (Mountain Knotgrass)'.
# There are 0 directories and 50 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Alpinia Galanga (Rasna)'.
# There are 0 directories and 125 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Amaranthus Viridis (Arive-Dantu)'.
# There are 0 directories and 69 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Andrographis Paniculata (Green Chireta)'.
# There are 0 directories and 65 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Anisomeles Malabarica (Malabar Catmint)'.
# There are 0 directories and 55 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Argemone Mexicana (Mexican Prickly Poppy)'.
# There are 0 directories and 67 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Artemisia Indica (Indian wormwood)'.
# There are 0 directories and 56 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Artocarpus Heterophyllus (Jackfruit)'.
# There are 0 directories and 60 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Azadirachta Indica (Neem)'.
# There are 0 directories and 103 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Basella Alba (Basale)'.
# There are 0 directories and 76 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Boerhavia Diffusa (Punarnava)'.
# There are 0 directories and 34 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Brassica Juncea (Indian Mustard)'.
# There are 0 directories and 66 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Calotropis Gigantea (Crown flower)'.
# There are 0 directories and 123 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Cardiospermum Halicacabum (Balloon vine)'.
# There are 0 directories and 74 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Carissa Carandas (Karanda)'.
# There are 0 directories and 55 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Catharanthus Roseus (Madagascar Periwinkle)'.
# There are 0 directories and 159 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Cissus Quadrangularis (Square Stalked Vine)'.
# There are 0 directories and 57 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Citrus Limon (Lemon)'.
# There are 0 directories and 51 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Clitoria Ternatea (Butterfly Pea)'.
# There are 0 directories and 51 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Coccinia Grandis (Ivy Gourd)'.
# There are 0 directories and 105 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Coleus Amboinicus (Mexican Mint)'.
# There are 0 directories and 58 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Commelina Benghalensis (Benghal dayflower)'.
# There are 0 directories and 73 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Corchorus Olitorius (Nalta Jute)'.
# There are 0 directories and 53 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Cucumis Maderaspatanus  (Madras Pea Pumpkin)'.
# There are 0 directories and 66 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Cyphostemma Setosum (Bristly Wild Grape)'.
# There are 0 directories and 57 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Datura Inoxia (Indian Thornapple)'.
# There are 0 directories and 68 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Dicliptera Paniculata (Panicled Foldwing)'.
# There are 0 directories and 83 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Euphorbia Hirta (Asthma Plant)'.
# There are 0 directories and 50 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Ficus Auriculata (Roxburgh fig)'.
# There are 0 directories and 63 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Ficus Religiosa (Peepal Tree)'.
# There are 0 directories and 55 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Gynandropsis Gynandra (Spiderwisp)'.
# There are 0 directories and 84 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Hemidesmus Indicus (Indian Sarsaparilla)'.
# There are 0 directories and 43 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Hibiscus Rosa-sinensis'.
# There are 0 directories and 59 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Hygrophila Spinosa (Kokilaksha)'.
# There are 0 directories and 71 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Jasminum (Jasmine)'.
# There are 0 directories and 81 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Jatropha Gossypiifolia (Bellyache bush)'.
# There are 0 directories and 64 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Kallstroemia Maxima (Big Caltrops)'.
# There are 0 directories and 62 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Mangifera Indica (Mango)'.
# There are 0 directories and 57 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Marsilea Minuta (Small Water Clover)'.
# There are 0 directories and 97 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Mentha (Mint)'.
# There are 0 directories and 77 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Moringa Oleifera (Drumstick)'.
# There are 0 directories and 72 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Mucuna Pruriens (Velvet bean)'.
# There are 0 directories and 56 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Muntingia Calabura (Jamaica Cherry-Gasagase)'.
# There are 0 directories and 60 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Murraya Koenigii (Curry)'.
# There are 0 directories and 62 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Nerium Oleander (Oleander)'.
# There are 0 directories and 40 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Nyctanthes Arbor-tristis (Parijata)'.
# There are 0 directories and 123 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Ocimum Basilicum (Sweet Basil)'.
# There are 0 directories and 53 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Ocimum Tenuiflorum (Tulsi)'.
# There are 0 directories and 66 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Passiflora Foetida (Stinking Passionflower)'.
# There are 0 directories and 105 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Phyllanthus Reticulatus (Black-Honey Shrub)'.
# There are 0 directories and 122 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Physalis Peruviana (Cape Gooseberry)'.
# There are 0 directories and 48 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Piper Betle (Betel)'.
# There are 0 directories and 48 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Plectranthus Amboinicus (Mexican Mint)'.
# There are 0 directories and 61 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Pongamia Pinnata (Indian Beech)'.
# There are 0 directories and 65 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Psidium Guajava (Guava)'.
# There are 0 directories and 79 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Punica Granatum (Pomegranate)'.
# There are 0 directories and 58 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Santalum Album (Sandalwood)'.
# There are 0 directories and 54 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Selenicereus Grandiflorus (Night blooming Cereus)'.
# There are 0 directories and 53 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Senna Alexandrina (Tinnevelly Senna)'.
# There are 0 directories and 66 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Senna Auriculata(Avaram)'.
# There are 0 directories and 60 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Sida Acuta (Common Wireweed)'.
# There are 0 directories and 69 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Sida Cordifolia (Country Mallow)'.
# There are 0 directories and 70 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Solanum Trilobatum (Purple Fruited Pea Eggplant)'.
# There are 0 directories and 65 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Spermacoce Articularis (Shaggy button weed)'.
# There are 0 directories and 39 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Syzygium Cumini (Jamun)'.
# There are 0 directories and 56 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Syzygium Jambos (Rose Apple)'.
# There are 0 directories and 56 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Tabernaemontana Divaricata (Crape Jasmine)'.
# There are 0 directories and 59 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Tephrosia Purpurea (Purple Tephrosia)'.
# There are 0 directories and 192 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Tinospora Cordifolia (heart-leaved moonseed)'.
# There are 0 directories and 63 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Tribulus Terrestris (Land Caltrops (Bindii))'.
# There are 0 directories and 60 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Tridax Procumbens (coatbuttons)'.
# There are 0 directories and 36 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Trigonella Foenum-graecum (Fenugreek)'.
# There are 0 directories and 106 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Urtica Dioica (Indian Stinging Nettle)'.
# There are 0 directories and 57 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Vitis Vinifera (Trellis Vine)'.
# There are 0 directories and 66 images in 'D:\COllege\CapStone\DataSet\Merged_Medicinal_Plant_dataset\Ziziphus Mauritiana (Indian Jujube)'.

# %% [markdown]
# ### Placing data into a Dataframe

# %%
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.png'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
image_df
# Out:
#                                                 Filepath  \
# 0      D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 1      D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 2      D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 3      D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 4      D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# ...                                                  ...
# 11145  D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 11146  D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 11147  D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 11148  D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
# 11149  D:\COllege\CapStone\DataSet\Merged_Medicinal_P...
#
#                                      Label
# 0           Abrus Precatorius (Rosary Pea)
# 1           Abrus Precatorius (Rosary Pea)
# 2           Abrus Precatorius (Rosary Pea)
# 3           Abrus Precatorius (Rosary Pea)
# 4           Abrus Precatorius (Rosary Pea)
# ...                                    ...
# 11145  Ziziphus Mauritiana (Indian Jujube)
# 11146  Ziziphus Mauritiana (Indian Jujube)
# 11147  Ziziphus Mauritiana (Indian Jujube)
# 11148  Ziziphus Mauritiana (Indian Jujube)
# 11149  Ziziphus Mauritiana (Indian Jujube)
#
# [11150 rows x 2 columns]

# %% [markdown]
# ### Visualizing images from the dataset

# %%
# Display 16 picture of the dataset with their labels
random_index = np.random.randint(0, len(image_df), 10)
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[random_index[i]]))
    ax.set_title(image_df.Label[random_index[i]])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
# Separate in train and test data
train_df, test_df = train_test_split(image_df, test_size=0.2, shuffle=True, random_state=42)

# %%
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input,
    validation_split=0.2
)

test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
)

# %%
# Split the data into three categories.
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 7136 validated image filenames belonging to 79 classes.
# Found 1784 validated image filenames belonging to 79 classes.
# Found 2230 validated image filenames belonging to 79 classes.

# %%
# Resize Layer
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(224,224),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %% [markdown]
# ### Training the model

# %%
# Load the pretained model
pretrained_model = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
# Create checkpoint callback
checkpoint_path = "plant_classification_model_checkpoint"
checkpoint_callback = ModelCheckpoint(checkpoint_path,
                                      save_weights_only=True,
                                      monitor="val_accuracy",
                                      save_best_only=True)

# %%
# Setup EarlyStopping callback to stop training if model's val_loss doesn't improve for 3 epochs
early_stopping = EarlyStopping(monitor = "val_loss", # watch the val loss metric
                               patience = 5,
                               restore_best_weights = True) # if val loss decreases for 3 epochs in a row, stop training

# %%
"""
inputs = pretrained_model.input
x = resize_and_rescale(inputs)

x = Dense(4096, activation='relu')(pretrained_model.output)
x = Dropout(0.2)(x)
x = Dense(4096, activation='relu')(x)
x = Dropout(0.2)(x)


outputs = Dense(79, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(
    optimizer=Adam(0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    steps_per_epoch=len(train_images),
    validation_data=val_images,
    validation_steps=len(val_images),
    epochs=10,
    callbacks=[
        early_stopping,
        create_tensorboard_callback("training_logs", 
                                    "plant_classification"),
        checkpoint_callback,
    ]
)

"""
# Out:
# '\ninputs = pretrained_model.input\nx = resize_and_rescale(inputs)\n\nx = Dense(4096, activation=\'relu\')(pretrained_model.output)\nx = Dropout(0.2)(x)\nx = Dense(4096, activation=\'relu\')(x)\nx = Dropout(0.2)(x)\n\n\noutputs = Dense(79, activation=\'softmax\')(x)\n\nmodel = Model(inputs=inputs, outputs=outputs)\nmodel.compile(\n    optimizer=Adam(0.0001),\n    loss=\'categorical_crossentropy\',\n    metrics=[\'accuracy\']\n)\n\nhistory = model.fit(\n    train_images,\n    steps_per_epoch=len(train_images),\n    validation_data=val_images,\n    validation_steps=len(val_images),\n    epochs=10,\n    callbacks=[\n        early_stopping,\n        create_tensorboard_callback("training_logs", \n                                    "plant_classification"),\n        checkpoint_callback,\n    ]\n)\n\n'

# %% [markdown]
# ### Saving the Model

# %%
#model.save('Herb_Prediction_VGGNET_16_MergedData.h5')

# %%
#model.summary()

# %% [markdown]
# ### Loading the Earlier saved model

# %%
model = tf.keras.models.load_model('Herb_Prediction_VGGNET_16_MergedData.h5')
#Check its architecture
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 79)                323663
# =================================================================
# Total params: 33,920,911
# Trainable params: 19,206,223
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### Model Evaluation

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.08666
# Test Accuracy: 98.97%

# %%
#plot_loss_curves(history)

# %% [markdown]
# ### Making predictions on the Test Data

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')
# Out:
# The first 5 predictions: ['Passiflora Foetida (Stinking Passionflower)', 'Kallstroemia Maxima (Big Caltrops)', 'Datura Inoxia (Indian Thornapple)', 'Clitoria Ternatea (Butterfly Pea)', 'Psidium Guajava (Guava)']

# %%
# Display 25 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_df) - 1, 15)
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(25,25),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath.iloc[random_index[i]]))
    if test_df.Label.iloc[random_index[i]] == pred[random_index[i]]:
      color = "green"
    else:
      color = "red"
    ax.set_title(f"True: {test_df.Label.iloc[random_index[i]]}\nPredicted: {pred[random_index[i]]}", color=color)
plt.show()
plt.tight_layout()

# %% [markdown]
# ### Plotting the Classification Reports and Confusion Matrix

# %%
y_test = list(test_df.Label)
print(classification_report(y_test, pred))
# Out:
#                                                    precision    recall  f1-score   support
#
#                    Abrus Precatorius (Rosary Pea)       1.00      0.86      0.92        35
#               Acalypha Indica (Indian CopperLeaf)       0.91      1.00      0.95        50
#         Achyranthes Aspera (Prickly Chaff Flower)       1.00      1.00      1.00        18
#                       Acorus Calamus (Sweet flag)       1.00      0.86      0.93        37
#                 Aerva Lanata (Mountain Knotgrass)       1.00      1.00      1.00        29
#                           Alpinia Galanga (Rasna)       1.00      1.00      1.00        24
#                  Amaranthus Viridis (Arive-Dantu)       1.00      0.94      0.97        49
#           Andrographis Paniculata (Green Chireta)       1.00      0.96      0.98        28
#           Anisomeles Malabarica (Malabar Catmint)       1.00      1.00      1.00        21
#         Argemone Mexicana (Mexican Prickly Poppy)       0.96      1.00      0.98        26
#                Artemisia Indica (Indian wormwood)       1.00      1.00      1.00        19
#              Artocarpus Heterophyllus (Jackfruit)       1.00      1.00      1.00        18
#                         Azadirachta Indica (Neem)       1.00      1.00      1.00        30
#                             Basella Alba (Basale)       1.00      1.00      1.00        39
#                     Boerhavia Diffusa (Punarnava)       0.92      1.00      0.96        24
#                  Brassica Juncea (Indian Mustard)       1.00      1.00      1.00        19
#                Calotropis Gigantea (Crown flower)       1.00      1.00      1.00        32
#          Cardiospermum Halicacabum (Balloon vine)       0.98      1.00      0.99        48
#                        Carissa Carandas (Karanda)       1.00      1.00      1.00        23
#       Catharanthus Roseus (Madagascar Periwinkle)       1.00      1.00      1.00        21
#       Cissus Quadrangularis (Square Stalked Vine)       0.98      1.00      0.99        63
#                              Citrus Limon (Lemon)       1.00      1.00      1.00        20
#                 Clitoria Ternatea (Butterfly Pea)       1.00      1.00      1.00        22
#                      Coccinia Grandis (Ivy Gourd)       1.00      1.00      1.00        25
#                  Coleus Amboinicus (Mexican Mint)       1.00      0.97      0.99        40
#        Commelina Benghalensis (Benghal dayflower)       1.00      1.00      1.00        23
#                  Corchorus Olitorius (Nalta Jute)       1.00      1.00      1.00        28
#      Cucumis Maderaspatanus  (Madras Pea Pumpkin)       1.00      1.00      1.00        22
#          Cyphostemma Setosum (Bristly Wild Grape)       0.93      0.93      0.93        29
#                 Datura Inoxia (Indian Thornapple)       1.00      1.00      1.00        25
#         Dicliptera Paniculata (Panicled Foldwing)       1.00      0.96      0.98        23
#                    Euphorbia Hirta (Asthma Plant)       1.00      1.00      1.00        32
#                   Ficus Auriculata (Roxburgh fig)       1.00      1.00      1.00        14
#                     Ficus Religiosa (Peepal Tree)       1.00      1.00      1.00        23
#                Gynandropsis Gynandra (Spiderwisp)       1.00      1.00      1.00        31
#          Hemidesmus Indicus (Indian Sarsaparilla)       1.00      0.97      0.98        30
#                            Hibiscus Rosa-sinensis       1.00      1.00      1.00        15
#                   Hygrophila Spinosa (Kokilaksha)       0.95      1.00      0.98        20
#                                Jasminum (Jasmine)       1.00      1.00      1.00        21
#           Jatropha Gossypiifolia (Bellyache bush)       1.00      1.00      1.00        36
#                Kallstroemia Maxima (Big Caltrops)       0.84      1.00      0.91        26
#                          Mangifera Indica (Mango)       1.00      1.00      1.00        27
#              Marsilea Minuta (Small Water Clover)       1.00      1.00      1.00        35
#                                     Mentha (Mint)       1.00      1.00      1.00        45
#                      Moringa Oleifera (Drumstick)       1.00      1.00      1.00        30
#                     Mucuna Pruriens (Velvet bean)       0.97      0.97      0.97        37
#      Muntingia Calabura (Jamaica Cherry-Gasagase)       1.00      1.00      1.00        22
#                          Murraya Koenigii (Curry)       1.00      1.00      1.00        24
#                        Nerium Oleander (Oleander)       1.00      1.00      1.00        26
#               Nyctanthes Arbor-tristis (Parijata)       1.00      1.00      1.00        13
#                    Ocimum Basilicum (Sweet Basil)       0.97      1.00      0.99        37
#                        Ocimum Tenuiflorum (Tulsi)       1.00      1.00      1.00        26
#       Passiflora Foetida (Stinking Passionflower)       1.00      1.00      1.00        22
#       Phyllanthus Reticulatus (Black-Honey Shrub)       1.00      1.00      1.00        49
#              Physalis Peruviana (Cape Gooseberry)       0.96      0.96      0.96        52
#                               Piper Betle (Betel)       1.00      1.00      1.00        21
#            Plectranthus Amboinicus (Mexican Mint)       1.00      1.00      1.00        25
#                   Pongamia Pinnata (Indian Beech)       1.00      1.00      1.00        41
#                           Psidium Guajava (Guava)       1.00      1.00      1.00        28
#                     Punica Granatum (Pomegranate)       1.00      1.00      1.00        33
#                       Santalum Album (Sandalwood)       1.00      1.00      1.00        19
# Selenicereus Grandiflorus (Night blooming Cereus)       1.00      1.00      1.00        24
#              Senna Alexandrina (Tinnevelly Senna)       1.00      1.00      1.00        18
#                          Senna Auriculata(Avaram)       1.00      1.00      1.00        23
#                      Sida Acuta (Common Wireweed)       1.00      1.00      1.00        25
#                  Sida Cordifolia (Country Mallow)       1.00      1.00      1.00        21
#  Solanum Trilobatum (Purple Fruited Pea Eggplant)       1.00      1.00      1.00        25
#       Spermacoce Articularis (Shaggy button weed)       0.95      1.00      0.98        21
#                           Syzygium Cumini (Jamun)       1.00      1.00      1.00        13
#                      Syzygium Jambos (Rose Apple)       1.00      1.00      1.00        19
#        Tabernaemontana Divaricata (Crape Jasmine)       1.00      1.00      1.00        18
#             Tephrosia Purpurea (Purple Tephrosia)       1.00      1.00      1.00        15
#      Tinospora Cordifolia (heart-leaved moonseed)       1.00      1.00      1.00        79
#      Tribulus Terrestris (Land Caltrops (Bindii))       1.00      1.00      1.00        22
#                   Tridax Procumbens (coatbuttons)       1.00      0.97      0.98        29
#             Trigonella Foenum-graecum (Fenugreek)       1.00      1.00      1.00        15
#            Urtica Dioica (Indian Stinging Nettle)       1.00      1.00      1.00        43
#                     Vitis Vinifera (Trellis Vine)       1.00      1.00      1.00        29
#               Ziziphus Mauritiana (Indian Jujube)       1.00      1.00      1.00        21
#
#                                          accuracy                           0.99      2230
#                                         macro avg       0.99      0.99      0.99      2230
#                                      weighted avg       0.99      0.99      0.99      2230

# %%
report = classification_report(y_test, pred, output_dict=True)
df = pd.DataFrame(report).transpose()
df
# Out:
#                                            precision    recall  f1-score  \
# Abrus Precatorius (Rosary Pea)              1.000000  0.857143  0.923077
# Acalypha Indica (Indian CopperLeaf)         0.909091  1.000000  0.952381
# Achyranthes Aspera (Prickly Chaff Flower)   1.000000  1.000000  1.000000
# Acorus Calamus (Sweet flag)                 1.000000  0.864865  0.927536
# Aerva Lanata (Mountain Knotgrass)           1.000000  1.000000  1.000000
# ...                                              ...       ...       ...
# Vitis Vinifera (Trellis Vine)               1.000000  1.000000  1.000000
# Ziziphus Mauritiana (Indian Jujube)         1.000000  1.000000  1.000000
# accuracy                                    0.989686  0.989686  0.989686
# macro avg                                   0.991696  0.991827  0.991439
# weighted avg                                0.990407  0.989686  0.989669
#
#                                                support
# Abrus Precatorius (Rosary Pea)               35.000000
# Acalypha Indica (Indian CopperLeaf)          50.000000
# Achyranthes Aspera (Prickly Chaff Flower)    18.000000
# Acorus Calamus (Sweet flag)                  37.000000
# Aerva Lanata (Mountain Knotgrass)            29.000000
# ...                                                ...
# Vitis Vinifera (Trellis Vine)                29.000000
# Ziziphus Mauritiana (Indian Jujube)          21.000000
# accuracy                                      0.989686
# macro avg                                  2230.000000
# weighted avg                               2230.000000
#
# [82 rows x 4 columns]

# %% [markdown]
# ### Checking for Random Images

# %%
from keras.preprocessing import image
img = image.load_img(r"C:\Users\appud\Downloads\Test_folder\im1.jpg",target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)

# %%
y_pred=model.predict(tf.expand_dims(img,axis=0))
print(y_pred)
y_pred = np.argmax(y_pred,axis=1)
print(y_pred)
# Out:
# [[2.2499702e-15 5.4418230e-09 1.2727896e-15 5.1236398e-08 2.9916019e-17
#   1.9096298e-12 3.3605830e-11 2.1946827e-15 1.0044416e-17 9.7454121e-11
#   2.9013650e-16 8.7715798e-14 2.5447740e-08 6.5689986e-17 1.3798686e-13
#   6.0779127e-14 4.1491717e-08 7.7793166e-14 8.3300450e-12 2.6724353e-08
#   1.2365086e-15 1.2130650e-14 8.3190188e-10 4.0050489e-12 2.8436992e-10
#   1.6195500e-13 7.0981998e-18 1.2681087e-14 4.7709143e-08 6.7801085e-09
#   1.6883694e-01 5.5120860e-16 9.1933346e-16 2.3754363e-11 2.6072148e-15
#   8.3227292e-07 3.5456128e-11 3.8872720e-12 6.1733696e-13 3.3608494e-09
#   2.0097737e-09 4.3399783e-14 1.3707474e-06 3.7228304e-14 1.4040846e-12
#   2.7663660e-07 7.6142519e-15 1.2570168e-14 1.9167489e-16 3.1106922e-16
#   1.0598366e-12 3.8307776e-10 7.8398590e-12 3.3814184e-13 4.5355438e-13
#   5.9713856e-09 2.1461455e-12 2.3540482e-11 7.4289441e-09 1.3969143e-17
#   8.0659712e-15 2.8759004e-08 4.1976495e-11 2.1133029e-13 1.2078540e-18
#   1.1532438e-14 1.0705066e-12 3.3997067e-17 5.6304402e-15 5.7894314e-13
#   9.8316896e-14 7.1382617e-15 8.3116025e-01 5.7778060e-16 6.5327178e-16
#   2.9394087e-16 1.3511678e-13 1.4448664e-12 6.3691330e-15]]
# [72]

# %%
# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in y_pred]


pred
#plt.imshow(img)
# Out:
# ['Tinospora Cordifolia (heart-leaved moonseed)']
